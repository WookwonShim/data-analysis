# %% [markdown]
# <a href="https://colab.research.google.com/github/WookwonShim/data-analysis/blob/main/2018_central_park_squirrel_census.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Loading and Preparation

# %%
from google.colab import drive
import pandas as pd
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Load data
squirrel = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/2018-central-park-squirrel-census-squirrel-data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Exploration: Squirrel Data

# %%
# Take a look at .info()
squirrel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Unique Squirrel ID                          3023 non-null   object
#  3   Hectare                                     3023 non-null   object
#  4   Shift                                       3023 non-null   object
#  5   Date                                        3023 non-null   int64
#  6   Hectare Squirrel Number                     3023 non-null   int64
#  7   Age                                         2902 non-null   object
#  8   Primary Fur Color                           2968 non-null   object
#  9   Highlight Fur Color                         1937 non-null   object
#  10  Combination of Primary and Highlight Color  3023 non-null   object
#  11  Color notes                                 182 non-null    object
#  12  Location                                    2959 non-null   object
#  13  Above Ground Sighter Measurement            2909 non-null   object
#  14  Specific Location                           476 non-null    object
#  15  Running                                     3023 non-null   bool
#  16  Chasing                                     3023 non-null   bool
#  17  Climbing                                    3023 non-null   bool
#  18  Eating                                      3023 non-null   bool
#  19  Foraging                                    3023 non-null   bool
#  20  Other Activities                            437 non-null    object
#  21  Kuks                                        3023 non-null   bool
#  22  Quaas                                       3023 non-null   bool
#  23  Moans                                       3023 non-null   bool
#  24  Tail flags                                  3023 non-null   bool
#  25  Tail twitches                               3023 non-null   bool
#  26  Approaches                                  3023 non-null   bool
#  27  Indifferent                                 3023 non-null   bool
#  28  Runs from                                   3023 non-null   bool
#  29  Other Interactions                          240 non-null    object
#  30  Lat/Long                                    3023 non-null   object
# dtypes: bool(13), float64(2), int64(2), object(14)
# memory usage: 463.6+ KB

# %%
# Take a look at a sample
squirrel.sample(n=5, random_state=28).T
# Out:
#                                                                                   1945  \
# X                                                                           -73.974718
# Y                                                                            40.769282
# Unique Squirrel ID                                                       5E-PM-1012-05
# Hectare                                                                            05E
# Shift                                                                               PM
# Date                                                                          10122018
# Hectare Squirrel Number                                                              5
# Age                                                                              Adult
# Primary Fur Color                                                             Cinnamon
# Highlight Fur Color                                                        Gray, White
# Combination of Primary and Highlight Color                        Cinnamon+Gray, White
# Color notes                                                                        NaN
# Location                                                                  Ground Plane
# Above Ground Sighter Measurement                                                 FALSE
# Specific Location                                                                  NaN
# Running                                                                           True
# Chasing                                                                          False
# Climbing                                                                         False
# Eating                                                                           False
# Foraging                                                                          True
# Other Activities                                                                   NaN
# Kuks                                                                             False
# Quaas                                                                            False
# Moans                                                                            False
# Tail flags                                                                       False
# Tail twitches                                                                    False
# Approaches                                                                        True
# Indifferent                                                                      False
# Runs from                                                                        False
# Other Interactions                                                             begging
# Lat/Long                                    POINT (-73.9747175419546 40.7692820030878)
#
#                                                                                   1174  \
# X                                                                           -73.955326
# Y                                                                            40.797559
# Unique Squirrel ID                                                      40D-PM-1013-04
# Hectare                                                                            40D
# Shift                                                                               PM
# Date                                                                          10132018
# Hectare Squirrel Number                                                              4
# Age                                                                              Adult
# Primary Fur Color                                                                 Gray
# Highlight Fur Color                                                           Cinnamon
# Combination of Primary and Highlight Color                               Gray+Cinnamon
# Color notes                                                                        NaN
# Location                                                                  Ground Plane
# Above Ground Sighter Measurement                                                 FALSE
# Specific Location                                                                  NaN
# Running                                                                           True
# Chasing                                                                          False
# Climbing                                                                         False
# Eating                                                                           False
# Foraging                                                                         False
# Other Activities                                                                   NaN
# Kuks                                                                             False
# Quaas                                                                            False
# Moans                                                                            False
# Tail flags                                                                       False
# Tail twitches                                                                    False
# Approaches                                                                       False
# Indifferent                                                                      False
# Runs from                                                                         True
# Other Interactions                                                                 NaN
# Lat/Long                                    POINT (-73.9553263156025 40.7975592060572)
#
#                                                                                  984   \
# X                                                                          -73.968172
# Y                                                                            40.78356
# Unique Squirrel ID                                                     22B-PM-1014-07
# Hectare                                                                           22B
# Shift                                                                              PM
# Date                                                                         10142018
# Hectare Squirrel Number                                                             7
# Age                                                                             Adult
# Primary Fur Color                                                                Gray
# Highlight Fur Color                                                          Cinnamon
# Combination of Primary and Highlight Color                              Gray+Cinnamon
# Color notes                                                                       NaN
# Location                                                                 Ground Plane
# Above Ground Sighter Measurement                                                FALSE
# Specific Location                                                                 NaN
# Running                                                                         False
# Chasing                                                                         False
# Climbing                                                                        False
# Eating                                                                          False
# Foraging                                                                        False
# Other Activities                                                                  NaN
# Kuks                                                                            False
# Quaas                                                                           False
# Moans                                                                           False
# Tail flags                                                                      False
# Tail twitches                                                                    True
# Approaches                                                                      False
# Indifferent                                                                      True
# Runs from                                                                       False
# Other Interactions                                                                NaN
# Lat/Long                                    POINT (-73.9681722244801 40.783559826281)
#
#                                                                                   663   \
# X                                                                           -73.956366
# Y                                                                            40.796682
# Unique Squirrel ID                                                      39D-AM-1008-03
# Hectare                                                                            39D
# Shift                                                                               AM
# Date                                                                          10082018
# Hectare Squirrel Number                                                              3
# Age                                                                              Adult
# Primary Fur Color                                                                 Gray
# Highlight Fur Color                                                                NaN
# Combination of Primary and Highlight Color                                       Gray+
# Color notes                                                                        NaN
# Location                                                                  Above Ground
# Above Ground Sighter Measurement                                                     5
# Specific Location                                                                  NaN
# Running                                                                          False
# Chasing                                                                          False
# Climbing                                                                          True
# Eating                                                                           False
# Foraging                                                                         False
# Other Activities                                                                   NaN
# Kuks                                                                             False
# Quaas                                                                            False
# Moans                                                                            False
# Tail flags                                                                       False
# Tail twitches                                                                    False
# Approaches                                                                       False
# Indifferent                                                                      False
# Runs from                                                                        False
# Other Interactions                                                                 NaN
# Lat/Long                                    POINT (-73.9563661256875 40.7966823114508)
#
#                                                                                   1757
# X                                                                           -73.960156
# Y                                                                            40.790051
# Unique Squirrel ID                                                      31E-PM-1006-08
# Hectare                                                                            31E
# Shift                                                                               PM
# Date                                                                          10062018
# Hectare Squirrel Number                                                              8
# Age                                                                              Adult
# Primary Fur Color                                                                 Gray
# Highlight Fur Color                                                           Cinnamon
# Combination of Primary and Highlight Color                               Gray+Cinnamon
# Color notes                                                                        NaN
# Location                                                                  Ground Plane
# Above Ground Sighter Measurement                                                 FALSE
# Specific Location                                                                  NaN
# Running                                                                          False
# Chasing                                                                          False
# Climbing                                                                         False
# Eating                                                                           False
# Foraging                                                                          True
# Other Activities                                                                   NaN
# Kuks                                                                             False
# Quaas                                                                            False
# Moans                                                                            False
# Tail flags                                                                       False
# Tail twitches                                                                    False
# Approaches                                                                       False
# Indifferent                                                                       True
# Runs from                                                                        False
# Other Interactions                                                                 NaN
# Lat/Long                                    POINT (-73.9601561064548 40.7900513933531)

# %%
# CONVERT DATA TYPES
# Convert the date from %m%d%Y to pd.datetime.
squirrel['Date'] = pd.to_datetime(squirrel['Date'], format='%m%d%Y')

squirrel['Hectare'].nunique() #339/3023 unique values
squirrel['Hectare'] = squirrel['Hectare'].astype('category') # Convert object to category.

squirrel['Shift'].unique() # AM or PM
squirrel['Shift'] = squirrel['Shift'].astype('category') # Convert object to category.

squirrel['Hectare Squirrel Number'].max() # max value 23
squirrel['Hectare Squirrel Number'].min() # min value 1
squirrel['Hectare Squirrel Number'] = squirrel['Hectare Squirrel Number'].astype('int8') # Convert int64 to int8.

squirrel.Age.unique() # [nan, 'Adult', 'Juvenile', '?']
squirrel['Age'] = squirrel['Age'].astype('category') # Convert object to category.
squirrel['Age'] = squirrel['Age'].replace('?', np.nan) # treat ? as a missing value, NaN

squirrel['Primary Fur Color'].unique() # [nan, 'Gray', 'Cinnamon', 'Black']
squirrel['Primary Fur Color'] = squirrel['Primary Fur Color'].astype('category') # Convert object to category.

squirrel['Highlight Fur Color'].unique() # has multiple categories. e.g., 'Gray', 'Cinnamon, White', 'Gray, White'

# Step 1: Split the multiple categories into a list of categories
squirrel['Highlight Fur Color'] = squirrel['Highlight Fur Color'].str.split(', ')

# Step 2: Handle NaN values by filling them with an empty list
squirrel['Highlight Fur Color'] = squirrel['Highlight Fur Color'].apply(lambda x: x if isinstance(x, list) else [])

# Step 3: Explode the list to get each category in its own row
exploded = squirrel.explode('Highlight Fur Color')

# Step 4: Create dummy variables for each unique category
dummies = pd.get_dummies(exploded['Highlight Fur Color'], prefix='highlight_color')

# Step 5: Group by the original index and sum to collapse back into the original rows
dummies = dummies.groupby(exploded.index).sum()

# Step 6: Combine the original DataFrame with the dummies DataFrame
squirrel = pd.concat([squirrel, dummies], axis=1)

squirrel['Location'].unique() # [nan, 'Above Ground', 'Ground Plane']
squirrel['Location'] = squirrel['Location'].astype('category') # Convert object to category.

# After converting the data types.
squirrel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 35 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Unique Squirrel ID                          3023 non-null   object
#  3   Hectare                                     3023 non-null   category
#  4   Shift                                       3023 non-null   category
#  5   Date                                        3023 non-null   datetime64[ns]
#  6   Hectare Squirrel Number                     3023 non-null   int8
#  7   Age                                         2898 non-null   category
#  8   Primary Fur Color                           2968 non-null   category
#  9   Highlight Fur Color                         3023 non-null   object
#  10  Combination of Primary and Highlight Color  3023 non-null   object
#  11  Color notes                                 182 non-null    object
#  12  Location                                    2959 non-null   category
#  13  Above Ground Sighter Measurement            2909 non-null   object
#  14  Specific Location                           476 non-null    object
#  15  Running                                     3023 non-null   bool
#  16  Chasing                                     3023 non-null   bool
#  17  Climbing                                    3023 non-null   bool
#  18  Eating                                      3023 non-null   bool
#  19  Foraging                                    3023 non-null   bool
#  20  Other Activities                            437 non-null    object
#  21  Kuks                                        3023 non-null   bool
#  22  Quaas                                       3023 non-null   bool
#  23  Moans                                       3023 non-null   bool
#  24  Tail flags                                  3023 non-null   bool
#  25  Tail twitches                               3023 non-null   bool
#  26  Approaches                                  3023 non-null   bool
#  27  Indifferent                                 3023 non-null   bool
#  28  Runs from                                   3023 non-null   bool
#  29  Other Interactions                          240 non-null    object
#  30  Lat/Long                                    3023 non-null   object
#  31  highlight_color_Black                       3023 non-null   int64
#  32  highlight_color_Cinnamon                    3023 non-null   int64
#  33  highlight_color_Gray                        3023 non-null   int64
#  34  highlight_color_White                       3023 non-null   int64
# dtypes: bool(13), category(5), datetime64[ns](1), float64(2), int64(4), int8(1), object(9)
# memory usage: 448.3+ KB

# %%
# ORDER AND RENAME COLUMNS
# Renaming columns in the DataFrame
renamed_columns = {
    'Unique Squirrel ID': 'unique_squirrel_id',
    'Hectare': 'hectare',
    'Hectare Squirrel Number': 'hectare_squirrel_number',
    'X': 'x',
    'Y': 'y',
    'Lat/Long': 'lat_long',
    'Date': 'date',
    'Shift': 'shift',
    'Age': 'age',
    'Primary Fur Color': 'primary_fur_color',
    'Highlight Fur Color': 'highlight_fur_color',
    'Combination of Primary and Highlight Color': 'combination_fur_color',
    'Color notes': 'color_notes',
    'Running': 'running',
    'Chasing': 'chasing',
    'Climbing': 'climbing',
    'Eating': 'eating',
    'Foraging': 'foraging',
    'Other Activities': 'other_activities',
    'Kuks': 'kuks',
    'Quaas': 'quaas',
    'Moans': 'moans',
    'Tail flags': 'tail_flags',
    'Tail twitches': 'tail_twitches',
    'Approaches': 'approaches',
    'Indifferent': 'indifferent',
    'Runs from': 'runs_from',
    'Other Interactions': 'other_interactions',
    'Location': 'location',
    'Above Ground Sighter Measurement': 'above_ground_sighter_measurement',
    'Specific Location': 'specific_location'
}

# Identification Columns
id_cols = [
    'unique_squirrel_id', 'hectare', 'hectare_squirrel_number'
]

# Location Columns
loc_cols = [
    'x', 'y', 'lat_long'
]

# Time Columns
time_cols = [
    'date', 'shift'
]

# Physical Characteristics
physical_char_cols = [
    'age', 'primary_fur_color', 'highlight_fur_color',
    'combination_fur_color', 'color_notes'
]

# Behavior Columns
behavior_cols = [
    'running', 'chasing', 'climbing', 'eating',
    'foraging', 'other_activities', 'kuks', 'quaas',
    'moans', 'tail_flags', 'tail_twitches', 'approaches',
    'indifferent', 'runs_from', 'other_interactions'
]

# Additional Location Details
other_loc_cols = [
    'location', 'above_ground_sighter_measurement', 'specific_location'
]

# Combined Ordered Columns
ordered_columns = (
    id_cols
    + loc_cols
    + time_cols
    + physical_char_cols
    + behavior_cols
    + other_loc_cols
)

# Applying the renaming and ordering to the DataFrame
squirrel = squirrel.rename(columns=renamed_columns)[ordered_columns]

# %%
# Take another look at a sample after data type conversion and updating column names
squirrel.sample(n=5, random_state=28).T
# Out:
#                                                                         1945  \
# unique_squirrel_id                                             5E-PM-1012-05
# hectare                                                                  05E
# hectare_squirrel_number                                                    5
# x                                                                 -73.974718
# y                                                                  40.769282
# lat_long                          POINT (-73.9747175419546 40.7692820030878)
# date                                                     2018-10-12 00:00:00
# shift                                                                     PM
# age                                                                    Adult
# primary_fur_color                                                   Cinnamon
# highlight_fur_color                                            [Gray, White]
# combination_fur_color                                   Cinnamon+Gray, White
# color_notes                                                              NaN
# running                                                                 True
# chasing                                                                False
# climbing                                                               False
# eating                                                                 False
# foraging                                                                True
# other_activities                                                         NaN
# kuks                                                                   False
# quaas                                                                  False
# moans                                                                  False
# tail_flags                                                             False
# tail_twitches                                                          False
# approaches                                                              True
# indifferent                                                            False
# runs_from                                                              False
# other_interactions                                                   begging
# location                                                        Ground Plane
# above_ground_sighter_measurement                                       FALSE
# specific_location                                                        NaN
#
#                                                                         1174  \
# unique_squirrel_id                                            40D-PM-1013-04
# hectare                                                                  40D
# hectare_squirrel_number                                                    4
# x                                                                 -73.955326
# y                                                                  40.797559
# lat_long                          POINT (-73.9553263156025 40.7975592060572)
# date                                                     2018-10-13 00:00:00
# shift                                                                     PM
# age                                                                    Adult
# primary_fur_color                                                       Gray
# highlight_fur_color                                               [Cinnamon]
# combination_fur_color                                          Gray+Cinnamon
# color_notes                                                              NaN
# running                                                                 True
# chasing                                                                False
# climbing                                                               False
# eating                                                                 False
# foraging                                                               False
# other_activities                                                         NaN
# kuks                                                                   False
# quaas                                                                  False
# moans                                                                  False
# tail_flags                                                             False
# tail_twitches                                                          False
# approaches                                                             False
# indifferent                                                            False
# runs_from                                                               True
# other_interactions                                                       NaN
# location                                                        Ground Plane
# above_ground_sighter_measurement                                       FALSE
# specific_location                                                        NaN
#
#                                                                        984   \
# unique_squirrel_id                                           22B-PM-1014-07
# hectare                                                                 22B
# hectare_squirrel_number                                                   7
# x                                                                -73.968172
# y                                                                  40.78356
# lat_long                          POINT (-73.9681722244801 40.783559826281)
# date                                                    2018-10-14 00:00:00
# shift                                                                    PM
# age                                                                   Adult
# primary_fur_color                                                      Gray
# highlight_fur_color                                              [Cinnamon]
# combination_fur_color                                         Gray+Cinnamon
# color_notes                                                             NaN
# running                                                               False
# chasing                                                               False
# climbing                                                              False
# eating                                                                False
# foraging                                                              False
# other_activities                                                        NaN
# kuks                                                                  False
# quaas                                                                 False
# moans                                                                 False
# tail_flags                                                            False
# tail_twitches                                                          True
# approaches                                                            False
# indifferent                                                            True
# runs_from                                                             False
# other_interactions                                                      NaN
# location                                                       Ground Plane
# above_ground_sighter_measurement                                      FALSE
# specific_location                                                       NaN
#
#                                                                         663   \
# unique_squirrel_id                                            39D-AM-1008-03
# hectare                                                                  39D
# hectare_squirrel_number                                                    3
# x                                                                 -73.956366
# y                                                                  40.796682
# lat_long                          POINT (-73.9563661256875 40.7966823114508)
# date                                                     2018-10-08 00:00:00
# shift                                                                     AM
# age                                                                    Adult
# primary_fur_color                                                       Gray
# highlight_fur_color                                                       []
# combination_fur_color                                                  Gray+
# color_notes                                                              NaN
# running                                                                False
# chasing                                                                False
# climbing                                                                True
# eating                                                                 False
# foraging                                                               False
# other_activities                                                         NaN
# kuks                                                                   False
# quaas                                                                  False
# moans                                                                  False
# tail_flags                                                             False
# tail_twitches                                                          False
# approaches                                                             False
# indifferent                                                            False
# runs_from                                                              False
# other_interactions                                                       NaN
# location                                                        Above Ground
# above_ground_sighter_measurement                                           5
# specific_location                                                        NaN
#
#                                                                         1757
# unique_squirrel_id                                            31E-PM-1006-08
# hectare                                                                  31E
# hectare_squirrel_number                                                    8
# x                                                                 -73.960156
# y                                                                  40.790051
# lat_long                          POINT (-73.9601561064548 40.7900513933531)
# date                                                     2018-10-06 00:00:00
# shift                                                                     PM
# age                                                                    Adult
# primary_fur_color                                                       Gray
# highlight_fur_color                                               [Cinnamon]
# combination_fur_color                                          Gray+Cinnamon
# color_notes                                                              NaN
# running                                                                False
# chasing                                                                False
# climbing                                                               False
# eating                                                                 False
# foraging                                                                True
# other_activities                                                         NaN
# kuks                                                                   False
# quaas                                                                  False
# moans                                                                  False
# tail_flags                                                             False
# tail_twitches                                                          False
# approaches                                                             False
# indifferent                                                             True
# runs_from                                                              False
# other_interactions                                                       NaN
# location                                                        Ground Plane
# above_ground_sighter_measurement                                       FALSE
# specific_location                                                        NaN

# %%
squirrel.describe(include=['object', 'category']).T # there seems to be a duplicate in unique_squirrel_id. why?
# Out:
#                                  count unique  \
# unique_squirrel_id                3023   3018
# hectare                           3023    339
# lat_long                          3023   3023
# shift                             3023      2
# age                               2898      2
# primary_fur_color                 2968      3
# highlight_fur_color               3023     11
# combination_fur_color             3023     22
# color_notes                        182    135
# other_activities                   437    307
# other_interactions                 240    197
# location                          2959      2
# above_ground_sighter_measurement  2909     41
# specific_location                  476    304
#
#                                                                                 top  \
# unique_squirrel_id                                                    7D-PM-1010-01
# hectare                                                                         14D
# lat_long                                 POINT (-73.9561344937861 40.7940823884086)
# shift                                                                            PM
# age                                                                           Adult
# primary_fur_color                                                              Gray
# highlight_fur_color                                                              []
# combination_fur_color                                                         Gray+
# color_notes                       Gray & Cinnamon selected as Primary. White sel...
# other_activities                                                            digging
# other_interactions                                                  runs from (dog)
# location                                                               Ground Plane
# above_ground_sighter_measurement                                              FALSE
# specific_location                                                              tree
#
#                                   freq
# unique_squirrel_id                   2
# hectare                             32
# lat_long                             1
# shift                             1676
# age                               2568
# primary_fur_color                 2473
# highlight_fur_color               1086
# combination_fur_color              895
# color_notes                          9
# other_activities                    19
# other_interactions                   9
# location                          2116
# above_ground_sighter_measurement  2116
# specific_location                   43

# %%
squirrel.describe(include=['object', 'category']).T
# Out:
#                                  count unique  \
# unique_squirrel_id                3023   3018
# hectare                           3023    339
# lat_long                          3023   3023
# shift                             3023      2
# age                               2898      2
# primary_fur_color                 2968      3
# highlight_fur_color               3023     11
# combination_fur_color             3023     22
# color_notes                        182    135
# other_activities                   437    307
# other_interactions                 240    197
# location                          2959      2
# above_ground_sighter_measurement  2909     41
# specific_location                  476    304
#
#                                                                                 top  \
# unique_squirrel_id                                                    7D-PM-1010-01
# hectare                                                                         14D
# lat_long                                 POINT (-73.9561344937861 40.7940823884086)
# shift                                                                            PM
# age                                                                           Adult
# primary_fur_color                                                              Gray
# highlight_fur_color                                                              []
# combination_fur_color                                                         Gray+
# color_notes                       Gray & Cinnamon selected as Primary. White sel...
# other_activities                                                            digging
# other_interactions                                                  runs from (dog)
# location                                                               Ground Plane
# above_ground_sighter_measurement                                              FALSE
# specific_location                                                              tree
#
#                                   freq
# unique_squirrel_id                   2
# hectare                             32
# lat_long                             1
# shift                             1676
# age                               2568
# primary_fur_color                 2473
# highlight_fur_color               1086
# combination_fur_color              895
# color_notes                          9
# other_activities                    19
# other_interactions                   9
# location                          2116
# above_ground_sighter_measurement  2116
# specific_location                   43

# %%
squirrel.describe(include=['number']) # Avg 4.12, median 3, Max 23
# Out:
#        hectare_squirrel_number            x            y
# count              3023.000000  3023.000000  3023.000000
# mean                  4.123718   -73.967184    40.780853
# std                   3.096492     0.007726     0.010285
# min                   1.000000   -73.981159    40.764911
# 25%                   2.000000   -73.973102    40.771676
# 50%                   3.000000   -73.968594    40.778166
# 75%                   6.000000   -73.960189    40.791219
# max                  23.000000   -73.949722    40.800119

# %%
squirrel[squirrel.hectare_squirrel_number > 20] # Hectare 14E has 3 sightings reported on the same day, same shift, for over 20 squirrels. are these the same group of squirrels reported multiple times? why?
# Out:
#      unique_squirrel_id hectare  hectare_squirrel_number          x  \
# 16       14E-AM-1008-23     14E                       23 -73.970393
# 1322     14E-AM-1008-21     14E                       21 -73.970182
# 1398     14E-AM-1008-22     14E                       22 -73.970443
#
#               y                                    lat_long       date shift  \
# 16    40.776503  POINT (-73.9703925210471 40.7765032004992) 2018-10-08    AM
# 1322  40.776370  POINT (-73.9701824376506 40.7763703306736) 2018-10-08    AM
# 1398  40.776376   POINT (-73.970442878377 40.7763755560359) 2018-10-08    AM
#
#         age primary_fur_color  ...  moans tail_flags tail_twitches  \
# 16    Adult              Gray  ...  False      False         False
# 1322  Adult              Gray  ...  False      False         False
# 1398  Adult              Gray  ...  False      False         False
#
#       approaches  indifferent  runs_from              other_interactions  \
# 16         False         True      False                             NaN
# 1322        True        False      False  curious,but not expecting food
# 1398       False         True      False                             NaN
#
#           location above_ground_sighter_measurement  specific_location
# 16    Ground Plane                            FALSE                NaN
# 1322  Ground Plane                            FALSE                NaN
# 1398  Ground Plane                            FALSE                NaN
#
# [3 rows x 31 columns]

# %%
squirrel[squirrel.hectare == '14E'][['unique_squirrel_id', 'hectare', 'hectare_squirrel_number', 'date', 'shift']].sort_values(by=['date', 'hectare_squirrel_number'])
# after examining the hectare 14E, it turns out it's the squirrel id for the hectare at the time. There were 23 squirrels.
# maybe the count was done across the park at the same time, by different individuals assigned to each hectare to avoid double count.

# 14E seems to be very popular, a complete outlier. what's the reason? maybe people giving food? check other_animal in hectare_data
# Out:
#      unique_squirrel_id hectare  hectare_squirrel_number       date shift
# 263      14E-AM-1008-01     14E                        1 2018-10-08    AM
# 90       14E-AM-1008-02     14E                        2 2018-10-08    AM
# 2005     14E-AM-1008-03     14E                        3 2018-10-08    AM
# 887      14E-AM-1008-04     14E                        4 2018-10-08    AM
# 135      14E-AM-1008-05     14E                        5 2018-10-08    AM
# 540      14E-AM-1008-06     14E                        6 2018-10-08    AM
# 556      14E-AM-1008-07     14E                        7 2018-10-08    AM
# 943      14E-AM-1008-08     14E                        8 2018-10-08    AM
# 79       14E-AM-1008-09     14E                        9 2018-10-08    AM
# 2920     14E-AM-1008-10     14E                       10 2018-10-08    AM
# 2664     14E-AM-1008-11     14E                       11 2018-10-08    AM
# 1696     14E-AM-1008-12     14E                       12 2018-10-08    AM
# 2121     14E-AM-1008-13     14E                       13 2018-10-08    AM
# 1905     14E-AM-1008-14     14E                       14 2018-10-08    AM
# 2268     14E-AM-1008-15     14E                       15 2018-10-08    AM
# 1566     14E-AM-1008-16     14E                       16 2018-10-08    AM
# 757      14E-AM-1008-17     14E                       17 2018-10-08    AM
# 2983     14E-AM-1008-18     14E                       18 2018-10-08    AM
# 521      14E-AM-1008-19     14E                       19 2018-10-08    AM
# 463      14E-AM-1008-20     14E                       20 2018-10-08    AM
# 1322     14E-AM-1008-21     14E                       21 2018-10-08    AM
# 1398     14E-AM-1008-22     14E                       22 2018-10-08    AM
# 16       14E-AM-1008-23     14E                       23 2018-10-08    AM
# 2120     14E-PM-1017-01     14E                        1 2018-10-17    PM
# 2642     14E-PM-1017-02     14E                        2 2018-10-17    PM
# 2773     14E-PM-1017-03     14E                        3 2018-10-17    PM
# 875      14E-PM-1017-04     14E                        4 2018-10-17    PM
# 941      14E-PM-1017-05     14E                        5 2018-10-17    PM

# %%
squirrel.describe(include=['bool']).T
# Out:
#               count unique    top  freq
# running        3023      2  False  2293
# chasing        3023      2  False  2744
# climbing       3023      2  False  2365
# eating         3023      2  False  2263
# foraging       3023      2  False  1588
# kuks           3023      2  False  2921
# quaas          3023      2  False  2973
# moans          3023      2  False  3020
# tail_flags     3023      2  False  2868
# tail_twitches  3023      2  False  2589
# approaches     3023      2  False  2845
# indifferent    3023      2  False  1569
# runs_from      3023      2  False  2345

# %%
top_5_hectare = squirrel.groupby('hectare')['unique_squirrel_id'].count().sort_values(ascending=False).head(5)
top_5_hectare # further check what correlates with the squirrel sighting frequency in a hectare.
# Out:
# hectare
# 14D    32
# 32E    30
# 14E    28
# 01B    27
# 07H    26
# Name: unique_squirrel_id, dtype: int64

# %%
top_primary_fur_color = squirrel.groupby('primary_fur_color')['unique_squirrel_id'].count().sort_values(ascending=False)
top_primary_fur_color # mostly gray. what's the temperature outside? is it the season that correlates with the color?
# Out:
# primary_fur_color
# Gray        2473
# Cinnamon     392
# Black        103
# Name: unique_squirrel_id, dtype: int64

# %%
behavior = squirrel[behavior_cols].select_dtypes('bool')
behavior.sum(axis=0).sort_values(ascending=False)
# Out:
# indifferent      1454
# foraging         1435
# eating            760
# running           730
# runs_from         678
# climbing          658
# tail_twitches     434
# chasing           279
# approaches        178
# tail_flags        155
# kuks              102
# quaas              50
# moans               3
# dtype: int64

# %%
squirrel[id_cols + loc_cols].sort_values(by='hectare')
# Out:
#      unique_squirrel_id hectare  hectare_squirrel_number          x  \
# 1175      1A-PM-1014-04     01A                        4 -73.980790
# 2935      1A-PM-1014-05     01A                        5 -73.980988
# 2490      1A-AM-1007-03     01A                        3 -73.980691
# 1054      1A-AM-1007-04     01A                        4 -73.981108
# 2386      1A-PM-1014-01     01A                        1 -73.980852
# ...                 ...     ...                      ...        ...
# 3007     42H-PM-1014-04     42H                        4 -73.950353
# 2909     42H-PM-1014-03     42H                        3 -73.950606
# 574      42I-PM-1014-03     42I                        3 -73.949722
# 2695     42I-PM-1014-01     42I                        1 -73.950146
# 1652     42I-PM-1014-02     42I                        2 -73.949842
#
#               y                                    lat_long
# 1175  40.768216   POINT (-73.9807898224726 40.768215817511)
# 2935  40.768322  POINT (-73.9809876538513 40.7683223242143)
# 2490  40.768115  POINT (-73.9806905259671 40.7681152210858)
# 1054  40.767516   POINT (-73.9811078442462 40.767515940567)
# 2386  40.768315  POINT (-73.9808517324721 40.7683154647217)
# ...         ...                                         ...
# 3007  40.797654  POINT (-73.9503533343658 40.7976543603953)
# 2909  40.797619  POINT (-73.9506062997507 40.7976189496674)
# 574   40.796517   POINT (-73.9497217674555 40.796517007214)
# 2695  40.797094   POINT (-73.9501457233643 40.797094356558)
# 1652  40.796940  POINT (-73.9498421746221 40.7969397424182)
#
# [3023 rows x 6 columns]

# %%
squirrel_count_per_hectare = squirrel.groupby('hectare')['unique_squirrel_id'].count().sort_values(ascending=False)
squirrel_count_per_hectare
# Out:
# hectare
# 14D    32
# 32E    30
# 14E    28
# 01B    27
# 07H    26
#        ..
# 26B     1
# 18E     1
# 24I     1
# 24B     1
# 23D     1
# Name: unique_squirrel_id, Length: 339, dtype: int64

# %%
squirrel_count_per_date = squirrel.groupby('date')['unique_squirrel_id'].count()
squirrel_count_per_date
# Out:
# date
# 2018-10-06    337
# 2018-10-07    405
# 2018-10-08    285
# 2018-10-10    335
# 2018-10-12    218
# 2018-10-13    434
# 2018-10-14    368
# 2018-10-17    216
# 2018-10-18    200
# 2018-10-19    158
# 2018-10-20     67
# Name: unique_squirrel_id, dtype: int64

# %%
# Group by date and hectare, then count the unique squirrel IDs
squirrel_count_per_date_hectare = squirrel.groupby(['hectare', 'date'])['unique_squirrel_id'].count()

# Sort each group in descending order based on the count of unique squirrel IDs
squirrel_count_per_date_hectare_sorted = squirrel_count_per_date_hectare.groupby(level=0, group_keys=False).apply(lambda x: x.sort_values(ascending=False))


# Display the sorted counts per date and hectare
#print(squirrel_count_per_date_hectare_sorted)

squirrel_count_per_date_hectare_sorted
# Out:
# hectare  date
# 01A      2018-10-14    7
#          2018-10-07    4
#          2018-10-06    0
#          2018-10-08    0
#          2018-10-10    0
#                       ..
# 42I      2018-10-13    0
#          2018-10-17    0
#          2018-10-18    0
#          2018-10-19    0
#          2018-10-20    0
# Name: unique_squirrel_id, Length: 3729, dtype: int64

# %% [markdown]
# # Data Exploration: Hectare Data

# %%
hectare = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/2018-central-park-squirrel-census-hectare-data.csv')

hectare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Hectare                        700 non-null    object
#  1   Shift                          700 non-null    object
#  2   Date                           700 non-null    int64
#  3   Anonymized Sighter             700 non-null    float64
#  4   Sighter Observed Weather Data  681 non-null    object
#  5   Litter                         319 non-null    object
#  6   Litter Notes                   6 non-null      object
#  7   Other Animal Sightings         668 non-null    object
#  8   Hectare Conditions             660 non-null    object
#  9   Hectare Conditions Notes       74 non-null     object
#  10  Number of sighters             700 non-null    int64
#  11  Number of Squirrels            700 non-null    int64
#  12  Total Time of Sighting         680 non-null    float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 71.2+ KB

# %%
hectare.head()

# take a look at sighters
# take a look at the time. the data dictionary wasn't available for hectare-data.
# see the num of squir
# litter is tracked? does it attrac squirrels?
# Out:
#   Hectare Shift      Date  Anonymized Sighter Sighter Observed Weather Data  \
# 0     01A    AM  10072018               110.0                  70º F, Foggy
# 1     01A    PM  10142018               177.0               54º F, overcast
# 2     01B    AM  10122018                11.0                  60º F, sunny
# 3     01B    PM  10192018               109.0            59.8º F, Sun, Cool
# 4     01C    PM  10132018               241.0          55° F, Partly Cloudy
#
#      Litter Litter Notes                    Other Animal Sightings  \
# 0      Some          NaN                           Humans, Pigeons
# 1  Abundant          NaN                           Humans, Pigeons
# 2      Some          NaN             Humans, Dogs, Pigeons, Horses
# 3      Some          NaN  Humans, Dogs, Pigeons, Sparrow, Blue jay
# 4       NaN          NaN              Humans, Dogs, Pigeons, Birds
#
#   Hectare Conditions Hectare Conditions Notes  Number of sighters  \
# 0               Busy                      NaN                   1
# 1               Busy                      NaN                   1
# 2               Busy                      NaN                   1
# 3               Busy                      NaN                   1
# 4               Busy                      NaN                   1
#
#    Number of Squirrels  Total Time of Sighting
# 0                    4                    22.0
# 1                    7                    26.0
# 2                   17                    23.0
# 3                   10                    35.0
# 4                   10                    25.0

# %%
hectare.columns.tolist()
# Out:
# ['Hectare',
#  'Shift',
#  'Date',
#  'Anonymized Sighter',
#  'Sighter Observed Weather Data',
#  'Litter',
#  'Litter Notes',
#  'Other Animal Sightings',
#  'Hectare Conditions',
#  'Hectare Conditions Notes',
#  'Number of sighters',
#  'Number of Squirrels',
#  'Total Time of Sighting']

# %%
col_map = {
    'Hectare'               : 'hectare',
    'Shift'                 : 'shift',
    'Date'                  : 'date',
    'Anonymized Sighter'    : 'sighter',
    'Sighter Observed Weather Data' : 'weather',
    'Litter'                : 'litter',
    'Litter Notes'          : 'litter_note',
    'Other Animal Sightings': 'other_animals',
    'Hectare Conditions'    : 'hectare_condition',
    'Hectare Conditions Notes': 'hectare_condition_note',
    'Number of sighters'    : 'num_of_sighters',
    'Number of Squirrels'   : 'hectare_squirrel_number',
    'Total Time of Sighting': 'total_time'
}

hectare = hectare.rename(columns=col_map)
hectare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   hectare                  700 non-null    object
#  1   shift                    700 non-null    object
#  2   date                     700 non-null    int64
#  3   sighter                  700 non-null    float64
#  4   weather                  681 non-null    object
#  5   litter                   319 non-null    object
#  6   litter_note              6 non-null      object
#  7   other_animals            668 non-null    object
#  8   hectare_condition        660 non-null    object
#  9   hectare_condition_note   74 non-null     object
#  10  num_of_sighters          700 non-null    int64
#  11  hectare_squirrel_number  700 non-null    int64
#  12  total_time               680 non-null    float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 71.2+ KB

# %%
num_of_sighters = hectare.sighter.nunique()

hectare[hectare.sighter == 189190] # num of sighters 2. probably sighter id 189 and 190 did it together
# Out:
#     hectare shift      date   sighter       weather litter litter_note  \
# 626     07C    PM  10202018  189190.0  62º F, Sunny    NaN         NaN
#
#                            other_animals hectare_condition  \
# 626  Humans, Dogs, Sparrows, Other Birds              Calm
#
#     hectare_condition_note  num_of_sighters  num_of_squirrels  total_time
# 626                    NaN                2                 6        23.0

# %%
hectare.num_of_sighters.value_counts()
# Out:
# num_of_sighters
# 1    610
# 2     80
# 3     10
# Name: count, dtype: int64

# %%
hectare['sighter'] = hectare['sighter'].astype('str').replace('\.0$', '', regex=True).replace('\.', '', regex=True)
hectare[hectare.num_of_sighters >= 2] # want to find a way to split sighter ids when grouped of 2 or 3.
# Out:
#     hectare shift      date    sighter        weather litter litter_note  \
# 601     19H    PM  10082018     164165         cloudy    NaN         NaN
# 611     01C    AM  10122018     225226    cool, sunny   Some         NaN
# 612     01D    PM  10072018       3334  80º F, Cloudy    NaN         NaN
# 613     01E    PM  10072018       3334   80º F, Sunny    NaN         NaN
# 614     01I    PM  10122018     225226    cold, sunny   Some         NaN
# ..      ...   ...       ...        ...            ...    ...         ...
# 695     09A    AM  10132018  179180181            NaN   Some         NaN
# 696     11F    PM  10062018        168            NaN   Some         NaN
# 697     12G    PM  10072018  106107108          80º F    NaN         NaN
# 698     12H    PM  10072018  106107108          79º F    NaN         NaN
# 699     26A    PM  10062018        185            NaN    NaN         NaN
#
#                                  other_animals hectare_condition  \
# 601                                        NaN              Calm
# 611                         Humans, Dogs, Cats              Calm
# 612            Humans, Dogs, Pigeons, Sparrows               NaN
# 613  Humans, Dogs, Pigeons,  Robins. Blue jays              Busy
# 614         Humans, Hawks, Dogs, Pigeons, Cats              Busy
# ..                                         ...               ...
# 695     Humans, Dogs, Pigeons, Rats, Blue jays              Busy
# 696                      Humans, Dogs, Pigeons              Busy
# 697                           Humans, Cat bird              Busy
# 698                           Humans, Sparrows              Busy
# 699                                Horse, Pony               NaN
#
#     hectare_condition_note  num_of_sighters  hectare_squirrel_number  \
# 601                    NaN                2                        1
# 611                    NaN                2                        2
# 612                    NaN                2                        7
# 613                    NaN                2                        3
# 614                    NaN                2                        4
# ..                     ...              ...                      ...
# 695                    NaN                3                       12
# 696                    NaN                3                        3
# 697                    NaN                3                        7
# 698                    NaN                3                        8
# 699                    NaN                3                        6
#
#      total_time
# 601         5.0
# 611        30.0
# 612        25.0
# 613        20.0
# 614        70.0
# ..          ...
# 695        20.0
# 696        26.0
# 697        29.0
# 698        30.0
# 699        30.0
#
# [90 rows x 13 columns]

# %%
set(squirrel.columns) - (set(squirrel.columns) - set(hectare.columns)) # common columns between the two sets.
# Out:
# {'date', 'hectare', 'hectare_squirrel_number', 'shift'}

# %%
hectare.hectare_condition.unique() # why is there 'Calm, Busy', it's contradictory.

hectare[hectare.hectare_condition == 'Calm, Busy'] # all the 'Calm, Busy' reporting is done by a group of two. Maybe it was concatnated after reporting individually in the same hectare?
# no, after reading the notes, it seems like it's when there's a separate path/area. e.g., 'Calm (in Park), Busy (on Road)' will assume the latter is true.
# Out:
#     hectare shift      date sighter                                  weather  \
# 183     13C    AM  10102018      83            71º F Cloudy and wicked humid
# 199     14B    PM  10142018     222                          57º F, overcast
# 212     14I    AM  10132018     240                            ~60º F, rainy
# 213     15A    PM  10172018     224  52º F, cloudy, light rain drops, chilly
# 318     21I    AM  10182018      37                             44º F, Sunny
# 324     22D    PM  10122018      16                             61º F, sunny
# 345     23H    PM  10192018      45                     60º F, Partly Cloudy
# 501     36C    PM  10132018      45                     56° F, Partly Cloudy
# 502     36C    AM  10142018     243                 50º F, Calm, Fair, Sunny
# 542     38F    PM  10132018     222                     56º F, partly cloudy
# 552     39B    PM  10142018     183                            57º F, Cloudy
# 560     39F    AM  10142018      17                      51º F, mostly sunny
# 588     41F    AM  10192018     183                     45º F, Sunny, Breezy
# 615     02B    PM  10132018  245246                     54° F, Sunny, Breezy
# 617     02C    PM  10132018  245246                     54° F, Sunny, Breezy
# 643     16H    PM  10142018    5253                               cool, dusk
# 667     25A    PM  10072018    3132         79º F, Humid. Overcast. No rain.
# 686     41E    PM  10132018  250251                     55º F, partly cloudy
#
#        litter litter_note                                      other_animals  \
# 183      Some         NaN          Humans, Dogs, Blue jay, Cardinal, Warbler
# 199      Some         NaN                           Humans, Dogs, Rat, Ducks
# 212       NaN         NaN                              Humans, Dogs, Pigeons
# 213       NaN         NaN                                      Humans, Birds
# 318  Abundant         NaN                              Humans, Dogs, Pigeons
# 324       NaN         NaN                          Humans, Pigeons, Sparrows
# 345      Some         NaN                                       Humans, Dogs
# 501       NaN         NaN  Humans, Dogs, Dogs (on path), Ducks & Geese (i...
# 502       NaN         NaN                                      Humans, Birds
# 542       NaN         NaN                     Humans, Small birds, Chipmunks
# 552       NaN         NaN          Humans, Hawks, Dogs, Chipmunks, Blue jays
# 560       NaN         NaN                            Humans, Dogs, Chipmunks
# 588       NaN         NaN                 Humans, Dogs, Geese, Mallard Nests
# 615       NaN         NaN            Humans, Dogs, Pigeons, Robins, Sparrows
# 617       NaN         NaN                           Humans, Robins, Sparrows
# 643      Some         NaN                                Humans, Dogs, Birds
# 667       NaN         NaN  Humans, Dogs, Raccoons, Little Birds, Raccoon ...
# 686      Some         NaN                   Humans, Dogs, Chipmunk, Sparrows
#
#     hectare_condition                             hectare_condition_note  \
# 183        Calm, Busy                       Sporadically punctuated busy
# 199        Calm, Busy                            Busy, calm off walkways
# 212        Calm, Busy                     Calm (in Park), Busy (on Road)
# 213        Calm, Busy                                   Busy at sidewalk
# 318        Calm, Busy    Busy near street, near empty on the playground.
# 324        Calm, Busy                                                NaN
# 345        Calm, Busy                               Busy on Running Path
# 501        Calm, Busy                                    Busy on West Dr
# 502        Calm, Busy         Calm in woods, busy outside with fund walk
# 542        Calm, Busy  Only small chunk near road was busy, the rest ...
# 552        Calm, Busy  Calm in woods, busy, music nearby w/ tambourin...
# 560        Calm, Busy                                         "no woods"
# 588        Calm, Busy                       Started busy, then very calm
# 615        Calm, Busy                                    West Drive Busy
# 617        Calm, Busy                          Fenced Areas / West Drive
# 643        Calm, Busy                                                NaN
# 667        Calm, Busy                       Calm on grass. Busy on road.
# 686        Calm, Busy                 Calm (in forest), Busy (near road)
#
#      num_of_sighters  hectare_squirrel_number  total_time
# 183                1                        4        20.0
# 199                1                        8        22.0
# 212                1                        1        21.0
# 213                1                        1        20.0
# 318                1                        0        20.0
# 324                1                        7        26.0
# 345                1                        1        17.0
# 501                1                        6        25.0
# 502                1                        4        40.0
# 542                1                        6        22.0
# 552                1                        6        20.0
# 560                1                        5        25.0
# 588                1                        0        21.0
# 615                2                        9        22.0
# 617                2                       12        24.0
# 643                2                        5        25.0
# 667                2                        1        21.0
# 686                2                        5        21.0

# %%
hectare.date = pd.to_datetime(hectare.date, format='%m%d%Y')

squirrel.merge(hectare, on=['date', 'hectare', 'shift'])

squirrel.shape
# Out:
# (3023, 31)

# %%
squirrel.merge(hectare, on=['date', 'hectare', 'shift'], how='left').head(3)
# Out:
#   unique_squirrel_id hectare  hectare_squirrel_number          x          y  \
# 0     37F-PM-1014-03     37F                        3 -73.956134  40.794082
# 1     21B-AM-1019-04     21B                        4 -73.968857  40.783783
# 2     11B-PM-1014-08     11B                        8 -73.974281  40.775534
#
#                                      lat_long       date shift  age  \
# 0  POINT (-73.9561344937861 40.7940823884086) 2018-10-14    PM  NaN
# 1  POINT (-73.9688574691102 40.7837825208444) 2018-10-19    AM  NaN
# 2  POINT (-73.97428114848522 40.775533619083) 2018-10-14    PM  NaN
#
#   primary_fur_color  ...   sighter                    weather litter  \
# 0               NaN  ...     243.0  59º F, overcast, SW 6 mph    NaN
# 1               NaN  ...  213214.0    Mid 40s, Clear, No Wind   Some
# 2              Gray  ...     234.0               Cool, Cloudy   Some
#
#    litter_note                 other_animals  hectare_condition  \
# 0          NaN                        Humans               Busy
# 1          NaN  Humans, Dogs, Pigeons, Birds               Calm
# 2          NaN          Humans, Dogs, Horses               Busy
#
#    hectare_condition_note  num_of_sighters num_of_squirrels  total_time
# 0                     NaN              1.0              3.0        24.0
# 1                     NaN              2.0              7.0        25.0
# 2                     NaN              1.0              8.0        18.0
#
# [3 rows x 41 columns]

# %%
squirrel[squirrel.hectare=='37F']
# Out:
#      unique_squirrel_id hectare  hectare_squirrel_number          x  \
# 0        37F-PM-1014-03     37F                        3 -73.956134
# 173      37F-PM-1014-01     37F                        1 -73.955443
# 825      37F-PM-1014-02     37F                        2 -73.955726
# 2568     37F-AM-1010-01     37F                        1 -73.955966
#
#               y                                     lat_long       date shift  \
# 0     40.794082   POINT (-73.9561344937861 40.7940823884086) 2018-10-14    PM
# 173   40.794567   POINT (-73.9554432393295 40.7945669054449) 2018-10-14    PM
# 825   40.793951  POINT (-73.95572635334891 40.7939505791448) 2018-10-14    PM
# 2568  40.794583   POINT (-73.9559663734409 40.7945828261377) 2018-10-10    AM
#
#            age primary_fur_color  ...  moans tail_flags tail_twitches  \
# 0          NaN               NaN  ...  False      False         False
# 173        NaN              Gray  ...  False      False         False
# 825   Juvenile              Gray  ...  False      False         False
# 2568     Adult              Gray  ...  False       True         False
#
#       approaches  indifferent  runs_from  other_interactions      location  \
# 0          False        False      False                 NaN           NaN
# 173        False        False       True                 NaN  Ground Plane
# 825        False         True      False                 NaN  Ground Plane
# 2568       False         True      False                 NaN  Above Ground
#
#      above_ground_sighter_measurement  specific_location
# 0                                 NaN                NaN
# 173                             FALSE                NaN
# 825                             FALSE               LAWN
# 2568                                4                NaN
#
# [4 rows x 31 columns]

# %%
hectare.other_animals.unique() # are there too many categories to explode this into columns? Also, how to see how many categories in here.
# Out:
# array(['Humans, Pigeons', 'Humans, Dogs, Pigeons, Horses',
#        'Humans, Dogs, Pigeons, Sparrow, Blue jay',
#        'Humans, Dogs, Pigeons, Birds', 'Humans', 'Humans, Dogs, Ducks',
#        'Humans, Dogs, Cats, Raccoons',
#        'Humans, Dogs, Pigeons, Ducks, Bluejay, Sparrow, Starling',
#        'Humans, Pigeons, Small birds', 'Humans, Dogs',
#        'Humans, Dogs, Pigeons, Downy Woodpecker, Sparrows',
#        'Humans, Small birds', 'Humans, Hawks, Dogs',
#        'Humans, Pigeons, Mice', 'Humans, Pigeons, Ducks, Geese', nan,
#        'Humans, Dogs, Birds', 'Humans, Dogs (off-leash)', 'Humans, Birds',
#        'Humans, Dogs, Pigeons',
#        'Humans, Dogs, Ducks, Cardinal, Small birds, Robin',
#        'Humans, Dogs, Birds, but not pigeons', 'Humans, Dogs, Sparrows',
#        'Humans, Dogs, Blue Jays', 'Humans, Dogs, Small birds, Dogs',
#        'Humans, Dogs, Birds, Song birds and Crows',
#        'Humans, Dogs, Pigeons, Rat',
#        'Humans, Dogs, Sparrows, Starlings, American robins',
#        'Humans, Dogs, Sparrows, Robin', 'Humans, Dogs, Other birds',
#        'Humans, Dogs, Pigeons, Tourists', 'Dogs', 'Humans, little Birds',
#        'Humans (Bikers, Runners), Dogs, Small birds',
#        'Humans, Horses, Birds', 'Humans, Birds, Cardinal',
#        'Humans, Dogs, Robins (Birds)', 'Humans (Very Few)',
#        'Humans, Dogs, Small birds', 'Humans, Dogs, Birds, Blue jays',
#        'Humans, Sparrow', 'Humans, Dogs, Pigeons, Small birds',
#        'Humans, Dogs, Pigeons, Mice, Sparrows',
#        'Humans, Dogs, Owls, Small birds', 'Humans, Dogs, Horses, Birds',
#        'Dogs, Pigeons, Small birds', 'Humans, Dogs, Wood Thrush',
#        'Blue jay', 'Humans, Hawks, Dogs, Small birds',
#        'Humans, Dogs, dogs off-leash :( , Birds',
#        'Humans, Dogs, Horse drawn carriage. Woodpecker',
#        'Humans, Dogs, Red Robins',
#        'Humans, Dogs, Pigeons, Small birds, Rat, Mice',
#        'Humans, Dogs, Pigeons, Tiny birds on trees',
#        'Humans, Dogs, Pigeons, Chickadees, Tour groups',
#        'Humans, Dogs, Robins, Small brown birds -- not sparrows',
#        'Humans, Dogs, Rat (with an apple core), Horses, Robin',
#        'Humans, Dogs, Horses', 'Humans, Ducks, Blue Jay, Horse!',
#        'Humans, Dogs, Blue jays, Robins', 'Humans, Horses',
#        'Humans, Dogs, Chickadees', 'Humans, Blue jays, Robins',
#        'Humans, Sparrows', 'Humans, Dogs, Rat',
#        'Humans, Dogs, Pigeons, Ducks, Geese', 'Humans, Waterfowl',
#        'Humans, Dogs, Pigeons, Various bird types',
#        'Humans, Dogs, Birds, Ducks', 'Humans, Dogs, Blue jay, Sparrows',
#        'Humans, Dogs, Mandarin Duck',
#        'Humans, Hawks, Dogs, Pigeons, Sparrows, blue jays',
#        'Humans, Dogs, Sparrows, Rats',
#        'Humans, Dogs, Blue jay, Cardinal, Warbler',
#        'Humans, Dogs, Pigeons, Cats, Birds, Ducks',
#        'Humans, Birds (non-pigeon)', 'Humans, Dogs, Sparrows, Robins',
#        'Humans, Dogs, Mice', 'Humans, Dogs, Pigeons, Finches, Sparrows',
#        'Woodpecker', 'Humans, Dogs, Rat, Ducks',
#        'Humans, Dogs, Robins, Horses', 'Humans, Dogs (Lots)',
#        'Humans, Dogs, Mandarin Ducks', 'Humans, Dogs, Crickets',
#        'mouse, Rats, Other birds', 'Humans, Birds, Mouse, Rat',
#        'Humans, Dogs, Bluebird, Chickadees',
#        'Humans, Dogs, Sparrows, Crickets, Blue jay',
#        'Humans, Birds (unknown), Chipmunk', 'Humans, Dogs, Butterflies',
#        'Humans, Dogs, Yoga Class', 'Humans, Dogs, Raccoon (Dead)',
#        'Humans, Dogs, Pigeons, other Birds',
#        'Humans, Dogs, Mouse or Baby Rat', 'Humans, Cats', 'Birds, Ducks',
#        'Humans, Dogs, Robin', 'Humans, Dogs, Pigeons, Cats',
#        'Dogs, Robins, Mourning Dove, Sparrow',
#        'Humans, Dogs, Robins, Blue jays', 'Humans, Dogs, Birds (lots)',
#        'Humans, Dogs, Robins (Many)',
#        'Humans, Dogs, Sparrows, Blue Finch-like Birds, Robins, Blackbirds',
#        'Humans, Dogs, Birds, but less Robins, Sparrows, Crows, Sterlings, Doves',
#        'Humans, Dogs, Robins, starling, Mourning dove, Finches, Sparrows',
#        'Humans, Blue jays, Cardinals, Sparrows, Titmice',
#        'Humans, Dogs, Pigeons, Robins, Blackbirds, Sparrows',
#        'Humans, Robin, Seagulls - lots flying high.',
#        'Humans, Dogs, Pigeons, Seagulls (3), Butterfly',
#        'Humans, Dogs, Jays', 'Humans, Dogs, Pigeons, Robins',
#        'Humans, Pigeons, Birds', 'Humans, Dogs, Chimney swifts, Blue jay',
#        'Bird', 'Humans, Dogs, Robins', 'Humans, Woodpecker',
#        'Humans, Dogs, Sparrows, Migratory birds (a distant V of 30-40 going south)',
#        'Humans, Dogs, Woodpecker, Blue jay, Robins',
#        'Humans, Pigeons, Sparrows', 'Humans, Dogs, Rats, Sparrows',
#        'Humans, Dogs, Pigeons, Birds (galore: House sparrows, House finch, Blue jay, etc.)',
#        'Humans, Dogs, Robins, Jays', 'Humans, Dogs, Falcons',
#        'Humans, Dogs, Horse (saw droppings)',
#        'Humans, Dogs, Sparrows, Crows, Cardinal',
#        'Humans, Dogs, Blue Jay, Rat, Bee, Sparrow',
#        'Humans, Few and calls of larger birds, but not visible',
#        'Humans, Dogs, Runners', 'Pigeons, Other birds',
#        'Humans, Dogs, Other Birds', 'Humans, Dogs, Warblers',
#        'Humans, Dogs, Pigeons, Song birds',
#        'Humans, Dogs, Pigeons, Ducks', 'Humans, Dogs, Seagull',
#        'Humans, Turtle (in water)', 'Butterfly',
#        'Humans, Dogs, Song birds',
#        'Humans, Dogs, Pigeons, Sparrows, Robins, Grackles',
#        'Humans, Dogs, Robins, Blue jay', 'Humans, Unknown birds',
#        'Humans, Ducks', 'Humans (runners), Dogs (1 off-leash), Seagulls?',
#        'Humans, Dogs, Hummingbird??', 'Humans, Dogs, Pigeons, Midges',
#        'Humans, Dogs, Birds (Other)', 'Humans, Dogs, Assorted Birds',
#        'Humans, Dogs, Lots of Birds', 'Humans, Blue jay',
#        'Humans, Dogs, Blackbird and other birds',
#        'Humans, Dogs, Pigeons, Sparrows',
#        'Humans, Dogs, Falcons, unknown bird',
#        'Humans, Dogs, Sparrows, Jays', 'Humans, Dogs, other Birds',
#        'Humans, Dogs, Chipmunk',
#        'Humans (lots of bikers), Dogs, Small birds',
#        'Humans, Dogs, Other Song birds',
#        'Humans, Dogs, Birds, Humans playing tennis',
#        'Humans, Dogs, Sparrows, Woodpecker',
#        'Humans, Dogs, Warbler (Internet says magnolia warbler), Unknown grey/brown bird',
#        'Humans, Dogs, blue jay',
#        'Humans, Dogs, Pigeons, Birds (Assorted)',
#        'Humans, Dogs, Falcons, Small birds',
#        'Humans, Dogs, Butterflies, Birds with red chest',
#        'Humans, Dogs, Many Small birds',
#        'Humans, Dogs, Children in costume',
#        'Humans, Dogs, Pigeons, Robins, Woodpeckers',
#        'Humans, Dogs, Rats, Ducks, Canada Geese',
#        'Humans, Dogs, Birds, No Pigeons', 'Humans, Hawks, Dogs, Blue jay',
#        'Humans, Dogs, Birds.', 'Humans, Dogs, Field mouse, Chipmunk',
#        'Humans, Dogs, Birds, Sparrows',
#        'Humans, Dogs, Pigeons, Chipmunk (?), Crickets',
#        'Humans, Birds (lots of screeching, not sure what kind of birds)',
#        'Humans, Dogs, Dogs (on path), Ducks & Geese (in pool)',
#        'Humans, Dogs, Turtle, Chipmunks', 'Humans, Dogs, Chipmunks',
#        'Humans, Robin', 'Dogs, lots of Blue jays & Gackels',
#        'Humans, Dogs, Many song birds: Wrens, Finches, Blue jays, Mourning dove',
#        'Humans, Dogs, Blue jays. Robins, Sparrows', 'Morning Dove, Crows',
#        'Chipmunks (2)', 'Humans, Blue Jay, Warbler',
#        'Humans, Falcon, Chipmunks', 'Humans, Chipmunks',
#        'Humans, Chipmunks, Lots of little birds',
#        'Humans, Dogs, Gull, Birds',
#        'Humans, Dogs, Mourning doves (sic), Sparrows',
#        'Humans, Dogs, Birds, Chipmunks', 'Humans, Dogs, Chipmunks (5+)',
#        'Humans, Birds, No Pigeons', 'Humans, Small birds, Chipmunks',
#        'Humans, Dogs, Migratory birds', 'Chipmunks',
#        'Humans, Chippys, Birds', 'Humans, So many Birds!',
#        'Humans, Dogs, Rats, Chipmunks',
#        'Humans, Hawks, Dogs, Chipmunks, Blue jays', 'Hawks, Chipmunk',
#        'Humans, Chipmunk, Warbler', 'Humans, Song birds', 'Robins?',
#        'Humans, Chipmunk, migratory birds', 'Humans (a trail runner)',
#        'Humans, Dogs, Ducks, Mainly female mallards, Canadian geese, also Small birds Sparrows?',
#        'Humans, Dogs, Finches', 'Humans, Dogs, Woodpecker, Chipmunk',
#        'Humans, Dogs, Geese', 'Humans, Hawks, Ducks',
#        'Humans, Dogs, Pigeons, Chipmunks', 'Dogs, Chipmunks (at least 3)',
#        'Humans, Birds. Chipmunks', 'Humans, Hawks, Dogs, Chipmunk',
#        'Humans, Dogs, Geese, Mallard Nests', 'Humans, Ducks, Birds',
#        'Humans, Dogs, Pigeons, Turtles, Ducks, Geese',
#        'Humans, Dogs, Pigeons, Geese, Ducks',
#        'Humans, Dogs, Pigeons, Rat, Chipmunk',
#        'Humans, Dogs, Birds, Chipmunks, Rats',
#        'Humans, Dogs, Pigeons, other Song birds',
#        'Humans, Dogs, Geese (a few)', 'Humans, Dogs, Cats',
#        'Humans, Dogs, Pigeons,  Robins. Blue jays',
#        'Humans, Hawks, Dogs, Pigeons, Cats',
#        'Humans, Dogs, Pigeons, Robins, Sparrows',
#        'Humans, Robins, Sparrows', 'Humans, Dogs, Pigeons, Chickadees',
#        'Humans (Notes), Dogs, Cats',
#        'Humans, Dogs, Birds, Rats (Fat), Inchworm',
#        'Humans, Dogs, Sparrows, Other Birds', 'Sparrows, Butterflies',
#        'Humans, Dogs, Rats (Notes)',
#        'Humans, Dogs, Sparrow, Starlings, Cardinals, Crows',
#        'Humans, Dogs, Birds, Mice', 'Humans, Dogs, Sparrows. Butterflies',
#        'Dogs, Birds', 'Humans, Dogs, Mallard, Sparrow', 'Birds',
#        'Humans, Dogs, Birds, Robins, Mourning Doves',
#        'Humans, Hawks, Dogs, Pigeons, Robin', 'Humans, Dogs, Sparrow',
#        'Humans, Dogs, Starlings, Sparrows, Blue jays',
#        'Humans, Rats (by reservoir)', 'Humans, Dogs, Little Birds',
#        'Humans, Dogs, Raccoons, Little Birds, Raccoon sleeping in tree',
#        'Pigeons, Robins', 'Ducks', 'Humans, Dogs, Chipmunk, Sparrow',
#        'Humans, Sleeping possum, Chipmunk, Blue jay',
#        'Humans, Dogs, Pigeons, Blue jays, American Robin, Chipmunk',
#        'Humans, Hawks, Chipmunks',
#        'Humans, Dogs, Chimney Swifts, Birds, Chipmunk',
#        'Humans, Pigeons, Chipmunk', 'Humans, Hawks, Dogs, Pigeons, Duck',
#        'Humans, Dogs, Chipmunk, Sparrows', 'Mallards, Canadian Geese',
#        'Humans, Hawks, Dogs, Pigeons, Geese', 'Pigeons',
#        'Humans, Dogs, Pigeons, Doves. Grackle Birds',
#        'Humans, Dogs, Pigeons, Rats, Blue jays', 'Humans, Cat bird',
#        'Horse, Pony'], dtype=object)
